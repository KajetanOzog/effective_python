# %% [markdown]
# # QucikSort
# ## Base case nlogn Average nlogn Worst n^2
# ### słabe gdy mamy posortowana tablice nie stabliny

# %%
def partition(arr, low, high):
    
    # Choose the pivot
    pivot = arr[high]
    
    # Index of smaller element and indicates 
    # the right position of pivot found so far
    i = low - 1
    
    # Traverse arr[low..high] and move all smaller
    # elements to the left side. Elements from low to 
    # i are smaller after every iteration
    for j in range(low, high):
        if arr[j] < pivot:
            i += 1
            swap(arr, i, j)
    
    # Move pivot after smaller elements and
    # return its position
    swap(arr, i + 1, high)
    return i + 1

# Swap function
def swap(arr, i, j):
    arr[i], arr[j] = arr[j], arr[i]

# The QuickSort function implementation
def quickSort(arr, low, high):
    if low < high:
        
        # pi is the partition return index of pivot
        pi = partition(arr, low, high)
        
        # Recursion calls for smaller elements
        # and greater or equals elements
        quickSort(arr, low, pi - 1)
        quickSort(arr, pi + 1, high)

arr = [3,2,5,1,4,6,7,4]
n = len(arr)

quickSort(arr, 0, n - 1)
    
for val in arr:
    print(val, end=" ")
# Out:
# 1 2 3 4 4 5 6 7

# %% [markdown]
# # MergeSort
# ## Base nlogn Average nlogn Worst nlogn, Space n
# ### stabilny

# %%
def merge(arr, left, mid, right):
    n1 = mid - left + 1
    n2 = right - mid

    # Create temp arrays
    L = [0] * n1
    R = [0] * n2

    # Copy data to temp arrays L[] and R[]
    for i in range(n1):
        L[i] = arr[left + i]
    for j in range(n2):
        R[j] = arr[mid + 1 + j]

    i = 0  # Initial index of first subarray
    j = 0  # Initial index of second subarray
    k = left  # Initial index of merged subarray

    # Merge the temp arrays back
    # into arr[left..right]
    while i < n1 and j < n2:
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1

    # Copy the remaining elements of L[],
    # if there are any
    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1

    # Copy the remaining elements of R[], 
    # if there are any
    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1

def merge_sort(arr, left, right):
    if left < right:
        mid = (left + right) // 2

        merge_sort(arr, left, mid)
        merge_sort(arr, mid + 1, right)
        merge(arr, left, mid, right)

def print_list(arr):
    for i in arr:
        print(i, end=" ")
    print()

arr = [12, 11, 13, 5, 6, 7]
print("Given array is")
print_list(arr)

merge_sort(arr, 0, len(arr) - 1)

print("\nSorted array is")
print_list(arr)

# %% [markdown]
# # Heap Sort
# ### Niestabilny
# ### budowa n wyciaganie nlogn

# %%
# Python program for implementation of heap Sort

# To heapify a subtree rooted with node i
# which is an index in arr[].
def heapify(arr, n, i):
    
     # Initialize largest as root
    largest = i 
    
    #  left index = 2*i + 1
    l = 2 * i + 1 
    
    # right index = 2*i + 2
    r = 2 * i + 2  

    # If left child is larger than root
    if l < n and arr[l] > arr[largest]:
        largest = l

    # If right child is larger than largest so far
    if r < n and arr[r] > arr[largest]:
        largest = r

    # If largest is not root
    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]  # Swap

        # Recursively heapify the affected sub-tree
        heapify(arr, n, largest)

# Main function to do heap sort
def heapSort(arr):
    
    n = len(arr) 

    # Build heap (rearrange array)
    for i in range(n // 2 - 1, -1, -1):
        heapify(arr, n, i)

    # One by one extract an element from heap
    for i in range(n - 1, 0, -1):
      
        # Move root to end
        arr[0], arr[i] = arr[i], arr[0] 

        # Call max heapify on the reduced heap
        heapify(arr, i, 0)

def printArray(arr):
    for i in arr:
        print(i, end=" ")
    print()

# Driver's code
arr = [9, 4, 3, 8, 10, 2, 5] 
n = len(arr) 

for i in range(n // 2 - 1, -1, -1):
    heapify(arr, n, i)
    
print(arr)
heapSort(arr)
print("Sorted array is ")
printArray(arr)
# Out:
# [10, 9, 5, 8, 4, 2, 3]
# Sorted array is
# 2 3 4 5 8 9 10

# %% [markdown]
# # Bin Search

# %%
def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return - 1

# %% [markdown]
# # Insertion sort

# %%
def insertionSort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1

        # Move elements of arr[0..i-1], that are
        # greater than key, to one position ahead
        # of their current position
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key

# A utility function to print array of size n
def printArray(arr):
    for i in range(len(arr)):
        print(arr[i], end=" ")
    print()

# Driver method

arr = [12, 11, 13, 5, 6]
insertionSort(arr)
printArray(arr)
# Out:
# 5 6 11 12 13

# %% [markdown]
# # Counting sort
# ## O(n+k) stabilne

# %%
def count_sort(input_array):
    # Finding the maximum element of input_array.
    M = max(input_array)

    # Initializing count_array with 0
    count_array = [0] * (M + 1)

    # Mapping each element of input_array as an index of count_array
    for num in input_array:
        count_array[num] += 1

    # Calculating prefix sum at every index of count_array
    for i in range(1, M + 1):
        count_array[i] += count_array[i - 1]

    # Creating output_array from count_array
    output_array = [0] * len(input_array)

    for i in range(len(input_array) - 1, -1, -1):
        output_array[count_array[input_array[i]] - 1] = input_array[i]
        count_array[input_array[i]] -= 1

    return output_array

input_array = [4, 3, 12, 1, 5, 5, 3, 9]

# Output array
output_array = count_sort(input_array)

for num in output_array:
    print(num, end=" ")
# Out:
# 1 3 3 4 5 5 9 12

# %% [markdown]
# # Radix sort
# ## Stabilne O(d * (n+k)) d to liczba cyfr w kluczach

# %%
def countingSort(arr, exp1):

    n = len(arr)

    # The output array elements that will have sorted arr
    output = [0] * (n)

    # initialize count array as 0
    count = [0] * (10)

    # Store count of occurrences in count[]
    for i in range(0, n):
        index = arr[i] // exp1
        count[index % 10] += 1

    # Change count[i] so that count[i] now contains actual
    # position of this digit in output array
    for i in range(1, 10):
        count[i] += count[i - 1]

    # Build the output array
    i = n - 1
    while i >= 0:
        index = arr[i] // exp1
        output[count[index % 10] - 1] = arr[i]
        count[index % 10] -= 1
        i -= 1

    # Copying the output array to arr[],
    # so that arr now contains sorted numbers
    i = 0
    for i in range(0, len(arr)):
        arr[i] = output[i]

# Method to do Radix Sort


def radixSort(arr):

    # Find the maximum number to know number of digits
    max1 = max(arr)

    # Do counting sort for every digit. Note that instead
    # of passing digit number, exp is passed. exp is 10^i
    # where i is current digit number
    exp = 1
    while max1 / exp >= 1:
        countingSort(arr, exp)
        exp *= 10


# Driver code
arr = [170, 45, 75, 90, 802, 24, 2, 66]

# Function Call
radixSort(arr)

for i in range(len(arr)):
    print(arr[i], end=" ")
# Out:
# 2 24 45 66 75 90 170 802

# %% [markdown]
# # Ordery

# %%
class Node:
	def __init__(self, val, left=None, right=None):
		self.value = val
		self.left = left
		self.right = right

def inorder(head):
	if head is None:
		return []
	res = []
	res.extend(inorder(head.left))
	res.append(head.value)
	res.extend(inorder(head.right))
	return res

def preorder(head):
	if head is None:
		return []
	res = [head.value]	
	res.extend(preorder(head.left))
	res.extend(preorder(head.right))
	return res


def postorder(head):
	if head is None:
		return []
	res = postorder(head.left)
	res.extend(postorder(head.right))
	res.append(head.value)
	return res


def rebuild(preorder, inorder):
	if not preorder or not inorder:
		return None
        
	root = Node(preorder[0])
	mid = inorder.index(preorder[0])
	root.left = rebuild(preorder[1:mid+1], inorder[0:mid])
	root.right = rebuild(preorder[mid+1:], inorder[mid+1:])
	return root

def rebuild2(postorder, inorder):
	if not postorder or not inorder:
		return None
	root = Node(postorder[~0])
	mid = inorder.index(postorder[~0])
	root.right = rebuild2(postorder[mid: len(postorder) - 1:], inorder[mid+1:])
	root.left = rebuild2(postorder[:mid], inorder[:mid])
	return root
	
    
F = Node('F')
E = Node('E')
D = Node('D')
C = Node('C', None, F)
B = Node('B', D, E)
A = Node('A', B, C)
print(inorder(A))
print(preorder(A))
print(postorder(A))
print(preorder(rebuild2(postorder(A),inorder(A))))
# Out:
# ['D', 'B', 'E', 'A', 'C', 'F']
# ['A', 'B', 'D', 'E', 'C', 'F']
# ['D', 'E', 'B', 'F', 'C', 'A']
# ['A', 'B', 'D', 'E', 'C', 'F']

# %% [markdown]
# # Hash Table

# %%
class HashTable:
    def __init__(self, size):
        self.size = size
        self.table = [[] for _ in range(size)]

    def _hash(self, key):
        """Oblicza wartość hasza dla klucza."""
        return hash(key) % self.size

    def insert(self, key, value):
        """Wstawia parę klucz-wartość do tablicy haszującej."""
        index = self._hash(key)
        for pair in self.table[index]:
            if pair[0] == key:
                pair[1] = value  # Aktualizacja wartości dla istniejącego klucza
                return
        self.table[index].append([key, value])

    def get(self, key):
        """Pobiera wartość z tablicy na podstawie klucza."""
        index = self._hash(key)
        for pair in self.table[index]:
            if pair[0] == key:
                return pair[1]
        return None  # Jeśli klucz nie istnieje

    def delete(self, key):
        """Usuwa klucz z tablicy haszującej."""
        index = self._hash(key)
        for i, pair in enumerate(self.table[index]):
            if pair[0] == key:
                del self.table[index][i]
                return

    def __repr__(self):
        return str(self.table)

# Przykład użycia:
hash_table = HashTable(10)
hash_table.insert("klucz1", "wartość1")
hash_table.insert("klucz2", "wartość2")
print(hash_table.get("klucz1"))  # wartość1
print(hash_table)                # Zawartość tablicy
hash_table.delete("klucz1")
print(hash_table)
# Out:
# wartość1
# [[['klucz1', 'wartość1']], [], [], [], [], [['klucz2', 'wartość2']], [], [], [], []]
# [[], [], [], [], [], [['klucz2', 'wartość2']], [], [], [], []]

# %% [markdown]
# # Hash map

# %%
class Node:
    """Reprezentuje pojedynczy węzeł przechowujący parę klucz-wartość."""
    def __init__(self, key, value):
        self.key = key
        self.value = value
        self.next = None

class HashMap:
    """Własna implementacja mapy haszującej."""
    def __init__(self, size=10):
        self.size = size
        self.buckets = [None] * size  # Tworzymy tablicę pustych kubełków

    def _hash(self, key):
        """Funkcja haszująca oblicza indeks na podstawie klucza."""
        return hash(key) % self.size

    def insert(self, key, value):
        """Wstawia lub aktualizuje parę klucz-wartość w mapie."""
        index = self._hash(key)
        if self.buckets[index] is None:
            # Jeśli kubełek jest pusty, tworzymy nowy węzeł
            self.buckets[index] = Node(key, value)
        else:
            # Przechodzimy przez łańcuch, aby znaleźć klucz lub dodać nowy
            current = self.buckets[index]
            while current:
                if current.key == key:
                    current.value = value  # Aktualizacja wartości
                    return
                if current.next is None:
                    break
                current = current.next
            # Dodajemy nowy węzeł na końcu łańcucha
            current.next = Node(key, value)

    def get(self, key):
        """Zwraca wartość powiązaną z kluczem lub None, jeśli klucz nie istnieje."""
        index = self._hash(key)
        current = self.buckets[index]
        while current:
            if current.key == key:
                return current.value
            current = current.next
        return None

    def delete(self, key):
        """Usuwa klucz z mapy haszującej."""
        index = self._hash(key)
        current = self.buckets[index]
        prev = None
        while current:
            if current.key == key:
                if prev is None:
                    # Usuwamy pierwszy element w kubełku
                    self.buckets[index] = current.next
                else:
                    # Usuwamy element z łańcucha
                    prev.next = current.next
                return
            prev = current
            current = current.next

    def __repr__(self):
        """Reprezentacja mapy haszującej."""
        result = []
        for i, bucket in enumerate(self.buckets):
            items = []
            current = bucket
            while current:
                items.append(f"{current.key}: {current.value}")
                current = current.next
            result.append(f"Bucket {i}: " + " -> ".join(items) if items else f"Bucket {i}: Empty")
        return "\n".join(result)

# Przykład użycia:
hash_map = HashMap(5)  # Tworzymy mapę haszującą o rozmiarze 5
hash_map.insert("klucz1", "wartość1")
hash_map.insert("klucz2", "wartość2")
hash_map.insert("klucz3", "wartość3")
hash_map.insert("klucz1", "nowa_wartość1")  # Aktualizacja wartości
hash_map.insert("klucz4", "wartość4")

print(hash_map)  # Wyświetlamy zawartość mapy
print(hash_map.get("klucz2"))  # Pobieramy wartość klucza "klucz2"
hash_map.delete("klucz2")  # Usuwamy klucz "klucz2"
print(hash_map)

# %%
from functools import reduce

def k_distance_neighbours(root, value, k):
	
	path = []
	def findnode(current):
		if current is None:
			return False
		if current == value:
			path.append(current)
			return True
		else: 
			if findnode(current.left):
				path.append(current.value)
			if findnode(current.right):
				path.append(current.value)
	
	def find_children_with_distance(current, distance):
		if current is None:
			return []
			
		if distance == 0:
			return [current]
		else:
			return find_children_with_distance(current.left, distance - 1) + find_children_with_distance(current.right, distance - 1)
		
	findnode(root)
	output = []
	print(path)
	if path:
		for i, n in enumerate(path):
			output += find_children_with_distance(n, k-i)
			
	return output

# %%
class Node:
	def __init__(self, val, left=None, right=None):
		self.value = val
		self.left = left
		self.right = right
		
F = Node('F')
E = Node('E')
D = Node('D')
C = Node('C', None, F)
B = Node('B', D, E)
A = Node('A', B, C)
print([x.value for x in k_distance_neighbours(A, A, 2)])
# Out:
# ...
# ['D', 'E', 'F']

# %%
inter = [[1,2], [4,5], [6,7], [5,6]]
inter.sort(key= lambda x: x[1])
print(inter)
# Out:
# [[1, 2], [4, 5], [5, 6], [6, 7]]
